# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
dataset=pd.read_csv("insurance_pre.csv")
encoder=OrdinalEncoder(categories=[['female','male']])
dataset['sex']=encoder.fit_transform(dataset[['sex']])
encoder=OrdinalEncoder(categories=[['yes','no']])
dataset['smoker']=encoder.fit_transform(dataset[['smoker']])
independent=dataset[['age', 'sex', 'bmi', 'children', 'smoker']]
dependent=dataset[['charges']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
list1=['squared_error', 'friedman_mse', 'absolute_error', 'poisson']
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=50,criterion = 'friedman_mse',random_state=0,max_features='log2')
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.8665740908582202

# %%
import pickle
filename="InsuranceChargesPred.sav"
pickle.dump(regressor,open(filename,'wb'))
loaded_module=pickle.load(open(filename,'rb'))
loaded_module.predict([[21,0,23,1,1]])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([2714.736059])
