# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor
params_grid={'n_estimators': [10,50,70,100], 'objective':['regression','binary'] , 'boosting_type':['gbdt','rf']}
grid=GridSearchCV(LGBMRegressor(), params_grid, verbose=3, refit=True, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\lightgbm\sklearn.py", line 1398, in fit
#     super().fit(
#     ~~~~~~~~~~~^
#         X,
#         ^^
# ...

# %%
print("Best Model:",format(grid.best_params_))
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
# Best Model: {'boosting_type': 'gbdt', 'n_estimators': 50, 'objective': 'regression'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.588395      0.194812         0.018494        0.009719
# 1        0.053690      0.013510         0.013019        0.002404
# 2        0.210700      0.060777         0.008073        0.001201
# 3        0.187827      0.038122         0.007908        0.000421
# 4        0.178739      0.006100         0.008631        0.000730
# 5        0.290085      0.064660         0.007352        0.000694
# 6        0.254139      0.009580         0.008982        0.000979
# 7        0.358263      0.052042         0.008460        0.002702
# 8        0.016020      0.002250         0.000000        0.000000
# 9        0.023690      0.005845         0.000000        0.000000
# 10       0.016720      0.005845         0.000000        0.000000
# 11       0.017634      0.002045         0.000000        0.000000
# ...
