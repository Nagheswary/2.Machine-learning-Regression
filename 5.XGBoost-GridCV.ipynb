# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

params_grid={'n_estimators': [10,50,70,100], 'learning_rate':[0.1,0.4], 'booster':['gbtree','gblinear']}
grid=GridSearchCV(XGBRegressor(), params_grid, verbose=3, refit=True, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     lear...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'booster': ['gbtree', 'gblinear'],
#                          'learning_rate': [0.1, 0.4],
#                          'n_estimators': [10, 50, 70, 100]},
#              verbose=3)

# %%
print("Best Model:",format(grid.best_params_))
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
# Best Model: {'booster': 'gbtree', 'learning_rate': 0.1, 'n_estimators': 50}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.161414      0.061532         0.013179        0.003938
# 1        0.118307      0.014926         0.016806        0.007825
# 2        0.106171      0.015293         0.010841        0.000623
# 3        0.143687      0.037822         0.015815        0.010173
# 4        0.054047      0.011207         0.017217        0.010707
# 5        0.090931      0.014110         0.016041        0.005532
# 6        0.117342      0.012826         0.009708        0.001309
# 7        0.133316      0.009666         0.011545        0.002371
# 8        0.017178      0.003618         0.013255        0.004657
# 9        0.040272      0.002636         0.018745        0.011089
# 10       0.033298      0.001079         0.008297        0.001232
# 11       0.040909      0.000816         0.009481        0.001177
# 12       0.014694      0.001403         0.010042        0.001593
# 13       0.027015      0.002332         0.011959        0.004966
# 14       0.038086      0.004031         0.009752        0.001528
# 15       0.046419      0.009961         0.010777        0.004247
#
#    param_booster  param_learning_rate  param_n_estimators  \
# 0         gbtree                  0.1                  10
# 1         gbtree                  0.1                  50
# 2         gbtree                  0.1                  70
# 3         gbtree                  0.1                 100
# 4         gbtree                  0.4                  10
# 5         gbtree                  0.4                  50
# 6         gbtree                  0.4                  70
# 7         gbtree                  0.4                 100
# 8       gblinear                  0.1                  10
# 9       gblinear                  0.1                  50
# 10      gblinear                  0.1                  70
# 11      gblinear                  0.1                 100
# 12      gblinear                  0.4                  10
# 13      gblinear                  0.4                  50
# 14      gblinear                  0.4                  70
# 15      gblinear                  0.4                 100
#
#                                                params  split0_test_score  \
# 0   {'booster': 'gbtree', 'learning_rate': 0.1, 'n...           0.767770
# 1   {'booster': 'gbtree', 'learning_rate': 0.1, 'n...           0.867670
# 2   {'booster': 'gbtree', 'learning_rate': 0.1, 'n...           0.863314
# 3   {'booster': 'gbtree', 'learning_rate': 0.1, 'n...           0.854921
# 4   {'booster': 'gbtree', 'learning_rate': 0.4, 'n...           0.867051
# 5   {'booster': 'gbtree', 'learning_rate': 0.4, 'n...           0.827029
# 6   {'booster': 'gbtree', 'learning_rate': 0.4, 'n...           0.818120
# 7   {'booster': 'gbtree', 'learning_rate': 0.4, 'n...           0.810393
# 8   {'booster': 'gblinear', 'learning_rate': 0.1, ...           0.490685
# 9   {'booster': 'gblinear', 'learning_rate': 0.1, ...           0.642198
# 10  {'booster': 'gblinear', 'learning_rate': 0.1, ...           0.658394
# 11  {'booster': 'gblinear', 'learning_rate': 0.1, ...           0.677236
# 12  {'booster': 'gblinear', 'learning_rate': 0.4, ...           0.642100
# 13  {'booster': 'gblinear', 'learning_rate': 0.4, ...           0.720543
# 14  {'booster': 'gblinear', 'learning_rate': 0.4, ...           0.733730
# 15  {'booster': 'gblinear', 'learning_rate': 0.4, ...           0.745122
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.717446           0.753457           0.742712
# 1            0.789526           0.882506           0.838755
# 2            0.782735           0.874945           0.835380
# 3            0.778366           0.862790           0.829512
# 4            0.784646           0.874717           0.829553
# 5            0.747246           0.817767           0.796326
# 6            0.736803           0.804282           0.793308
# 7            0.731032           0.790183           0.793783
# 8            0.459314           0.465902           0.475165
# 9            0.612512           0.658608           0.624883
# 10           0.628397           0.674980           0.638946
# 11           0.646558           0.691636           0.655125
# 12           0.613805           0.657736           0.625002
# 13           0.684348           0.728199           0.691493
# 14           0.694812           0.741480           0.703863
# 15           0.703539           0.754622           0.715447
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.744688         0.745214        0.016458                8
# 1            0.850652         0.845821        0.031830                1
# 2            0.843645         0.840004        0.031870                3
# 3            0.833467         0.831811        0.029524                4
# 4            0.847186         0.840631        0.032125                2
# 5            0.800010         0.797676        0.027625                5
# 6            0.788284         0.788159        0.027646                6
# 7            0.779288         0.780936        0.026875                7
# 8            0.489606         0.476134        0.012504               16
# 9            0.653081         0.638256        0.017269               15
# 10           0.667598         0.653663        0.017470               13
# 11           0.683832         0.670878        0.017197               12
# 12           0.653408         0.638410        0.016717               14
# 13           0.718786         0.708674        0.017386               11
# 14           0.730726         0.720922        0.018196               10
# 15           0.741707         0.732087        0.019298                9
